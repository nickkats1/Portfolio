# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
from tools.config import load_config
import numpy as np
from pypfopt import expected_returns
import os
import yfinance as yf

class Sim:
    def __init__(self,config):
        self.config = config


    def fetch_yfinance_data(self) -> pd.DataFrame:
        """ Fetch Data from yfinance API """
        
        # all prices include SP&500
        all_prices = yf.download(tickers=self.config['combined_assets'],start=self.config['start_date'],end=self.config['end_date'])['Close']
        all_prices = all_prices.dropna()
        all_prices.drop_duplicates(inplace=True)

        return all_prices


    def single_index_model(self,output_dir="images/sim/"):

        #tickers to turn data into correct frame
        all_prices = self.fetch_yfinance_data()

        sp500_ticker = self.config['sp500_ticker']
        tickers = self.config['combined_assets']
        risk_free_rate = self.config['risk_free_rate']

        # sp500 data
        sp500_data = all_prices[sp500_ticker]
        # Market Returns(sp500) and Market Excess Returns
        market_returns = sp500_data.pct_change().dropna()
        #market index risk is of the sp500(variance(sp500))
        market_index_risk = np.var(market_returns)
        print(f'Market Index Risk: {market_index_risk}')




        # alphas, betas, total risk, covariance, market index risk,firm specific risk,product of betas
        alphas = {}
        betas = {}
        error_terms = {}
        adjusted_betas = {}
        firm_specific_risks = {}
        systematic_risks = {}
        total_risks = {}
        risk_premiums = {}
        Expected_Returns = {}
    







        for ticker in tickers:
            asset_data = all_prices[ticker]
            returns = asset_data.pct_change().dropna()
            Excess_Returns = asset_data.pct_change().dropna() - risk_free_rate
            print(f'Returns for: {ticker}, {returns}')
            print(f'Excess Returns: {Excess_Returns}')
            print(f'Market Returns: {sp500_ticker},{market_returns};-----')
            
            # CAPM expected returns
            capm_returns = expected_returns.capm_return(asset_data,market_prices=sp500_data,risk_free_rate=self.config['risk_free_rate'])
            


            model = sm.OLS(exog=sm.add_constant(market_returns),endog=returns).fit()
            

            # alpha, beta, error-term (e), firm-specific risk(variance(e)), market risk(variance of sp500 in this case).
            # risk premium: E(R) - Rf
            alpha = model.params.const
            beta = model.params.iloc[1]
            residuals = model.resid
            




            # adjusted beta: 2/3 * beta + 1/3 * 1
            adj_beta = (2/3) * beta + (1/3) * 1


            # Systematic risk is (Beta**2) * Market Index Risk (defined above)
            systematic_risk = (beta**2) * market_index_risk

            #  firm-specific risk is the variance of the "Unanticipated surprises" (the variance of the residuals for the asset)
            firm_specific_risk = np.var(residuals)

            # total risk = systematic Risk + Firm Specific Risk
            total_risk = systematic_risk + firm_specific_risk






            alphas[ticker] = alpha
            betas[ticker] = beta
            error_terms[ticker] = residuals
            adjusted_betas[ticker] = adj_beta
            systematic_risks[ticker] = systematic_risk
            firm_specific_risks[ticker] = firm_specific_risk
            total_risks[ticker] = total_risk
            
            # values to .csv


            print(f"CAPM Returns: {capm_returns}")
            print(f'Alpha Value: {alpha:.4f}')
            print(f'Beta Value: {beta:.4f}')
            print(f'Adjusted Beta: {adj_beta:4f}')
            print(f'Firm Specific Risk: {firm_specific_risk:.4f}')
            print(f'Systematic Risk: {systematic_risk:.4f}')
            print(f'Total Risk: {total_risk}')
            print(f'Error Term: {residuals}')

            


        

            # E(r) -> The Expected Return using pyportfolio & Risk Premiun = E(r) - rf 
            Expected_Return = expected_returns.mean_historical_return(asset_data)
            risk_premium = Expected_Return - risk_free_rate

            Expected_Returns[ticker] = Expected_Return
            risk_premiums[ticker] = risk_premium
            

            
            # for the individual betas and alphas

            print(f'ANOVA Table: {model.summary()}')
            print(f'R2 Score: {model.rsquared*100:.2f}')
            print(f'Expected Return: {Expected_Return}')


            



            ## plots
            plt.figure(figsize=(12,6))
            sns.scatterplot(x=market_returns, y=returns, label=ticker)
            sns.lineplot(x=market_returns, y=model.fittedvalues, color='red', label='Security Market Line')
                
            plt.title(f'Single Index Model for {ticker}')
            plt.xlabel('Market Excess Return')
            plt.ylabel(f'{ticker} Excess Return')
            plt.legend()
            os.makedirs(output_dir, exist_ok=True)
            plt.savefig(os.path.join(output_dir, f"single_index_model_{ticker}.png"))
            plt.show()



if __name__ == "__main__":
    config = load_config()
    sim_config = Sim(config)
    sim_config.fetch_yfinance_data()
    sim_config.single_index_model()
# Out:
# /tmp/ipykernel_165548/2027752277.py:20: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   all_prices = yf.download(tickers=self.config['combined_assets'],start=self.config['start_date'],end=self.config['end_date'])['Close']
# [*********************100%***********************]  31 of 31 completed
# /tmp/ipykernel_165548/2027752277.py:20: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   all_prices = yf.download(tickers=self.config['combined_assets'],start=self.config['start_date'],end=self.config['end_date'])['Close']
# [*********************100%***********************]  31 of 31 completed
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Market Index Risk: 0.00011532164066975064
# Returns for: AAPL, Date
# 2020-12-24    0.007713
# 2020-12-28    0.035765
# 2020-12-29   -0.013315
# 2020-12-30   -0.008527
# 2020-12-31   -0.007703
#                 ...
# 2025-11-06   -0.001370
# 2025-11-07   -0.004819
# 2025-11-10    0.004549
# 2025-11-11    0.021601
# 2025-11-12   -0.006467
# Name: AAPL, Length: 1227, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.001487
# 2020-12-28    0.026565
# 2020-12-29   -0.022515
# 2020-12-30   -0.017727
# 2020-12-31   -0.016903
#                 ...
# 2025-11-06   -0.010570
# 2025-11-07   -0.014019
# 2025-11-10   -0.004651
# 2025-11-11    0.012401
# 2025-11-12   -0.015667
# Name: AAPL, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: AAPL    0.167739
# Name: mkt, dtype: float64
# Alpha Value: 0.0001
# Beta Value: 1.2552
# Adjusted Beta: 1.170127
# Firm Specific Risk: 0.0001
# Systematic Risk: 0.0002
# Total Risk: 0.0003145379047194624
# Error Term: Date
# 2020-12-24    0.003200
# 2020-12-28    0.024744
# 2020-12-29   -0.010592
# 2020-12-30   -0.010284
# 2020-12-31   -0.015858
#                 ...
# 2025-11-06    0.012588
# 2025-11-07   -0.006476
# 2025-11-10   -0.014856
# 2025-11-11    0.018923
# 2025-11-12   -0.007330
# Length: 1227, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.578
# Model:                            OLS   Adj. R-squared:                  0.577
# Method:                 Least Squares   F-statistic:                     1675.
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):          1.61e-231
# Time:                        13:15:02   Log-Likelihood:                 3735.2
# No. Observations:                1227   AIC:                            -7466.
# Df Residuals:                    1225   BIC:                            -7456.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.329e-05      0.000      0.222      0.824      -0.001       0.001
# ^GSPC          1.2552      0.031     40.931      0.000       1.195       1.315
# ==============================================================================
# Omnibus:                      111.899   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              632.232
# Skew:                           0.175   Prob(JB):                    5.16e-138
# Kurtosis:                       6.499   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 57.76
# Expected Return: AAPL    0.169699
# dtype: float64
# Returns for: MSFT, Date
# 2020-12-24    0.007827
# 2020-12-28    0.009922
# 2020-12-29   -0.003601
# 2020-12-30   -0.011019
# 2020-12-31    0.003338
#                 ...
# 2025-11-06   -0.019836
# 2025-11-07   -0.000563
# 2025-11-10    0.018478
# 2025-11-11    0.005296
# 2025-11-12    0.004836
# Name: MSFT, Length: 1227, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.001373
# 2020-12-28    0.000722
# 2020-12-29   -0.012801
# 2020-12-30   -0.020219
# 2020-12-31   -0.005862
#                 ...
# 2025-11-06   -0.029036
# 2025-11-07   -0.009763
# 2025-11-10    0.009278
# 2025-11-11   -0.003904
# 2025-11-12   -0.004364
# Name: MSFT, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: MSFT    0.155965
# Name: mkt, dtype: float64
# Alpha Value: 0.0002
# Beta Value: 1.1620
# Adjusted Beta: 1.107982
# Firm Specific Risk: 0.0001
# Systematic Risk: 0.0002
# Total Risk: 0.00026453074842075334
# Error Term: Date
# 2020-12-24    0.003523
# 2020-12-28   -0.000408
# 2020-12-29   -0.001207
# 2020-12-30   -0.012773
# 2020-12-31   -0.004338
#                 ...
# 2025-11-06   -0.007042
# 2025-11-07   -0.002224
# 2025-11-10    0.000387
# 2025-11-11    0.002690
# 2025-11-12    0.003910
# Length: 1227, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MSFT   R-squared:                       0.589
# Model:                            OLS   Adj. R-squared:                  0.588
# Method:                 Least Squares   F-statistic:                     1753.
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):          1.60e-238
# Time:                        13:15:02   Log-Likelihood:                 3857.6
# No. Observations:                1227   AIC:                            -7711.
# Df Residuals:                    1225   BIC:                            -7701.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.000      0.652      0.515      -0.000       0.001
# ^GSPC          1.1620      0.028     41.865      0.000       1.108       1.216
# ==============================================================================
# Omnibus:                      223.203   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3665.921
# Skew:                           0.309   Prob(JB):                         0.00
# Kurtosis:                      11.445   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 58.86
# Expected Return: MSFT    0.19756
# dtype: float64
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: TGT, Date
# 2020-12-24    0.001601
# 2020-12-28    0.006850
# 2020-12-29   -0.007654
# 2020-12-30   -0.006627
# 2020-12-31    0.015240
#                 ...
# 2025-11-06   -0.030346
# 2025-11-07    0.023444
# 2025-11-10   -0.005590
# 2025-11-11    0.009368
# 2025-11-12    0.016254
# Name: TGT, Length: 1227, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.007599
# 2020-12-28   -0.002350
# 2020-12-29   -0.016854
# 2020-12-30   -0.015827
# 2020-12-31    0.006040
#                 ...
# 2025-11-06   -0.039546
# 2025-11-07    0.014244
# 2025-11-10   -0.014790
# 2025-11-11    0.000168
# 2025-11-12    0.007054
# Name: TGT, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: TGT    0.134086
# Name: mkt, dtype: float64
# Alpha Value: -0.0007
# Beta Value: 0.9888
# Adjusted Beta: 0.992502
# Firm Specific Risk: 0.0004
# Systematic Risk: 0.0001
# Total Risk: 0.000492489468779283
# Error Term: Date
# 2020-12-24   -0.001183
# 2020-12-28   -0.001061
# 2020-12-29   -0.004738
# 2020-12-30   -0.007240
# 2020-12-31    0.009587
#                 ...
# 2025-11-06   -0.018580
# 2025-11-07    0.022909
# 2025-11-10   -0.020104
# 2025-11-11    0.008030
# 2025-11-12    0.016345
# Length: 1227, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    TGT   R-squared:                       0.229
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                     363.7
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):           3.34e-71
# Time:                        13:15:03   Log-Likelihood:                 3090.9
# No. Observations:                1227   AIC:                            -6178.
# Df Residuals:                    1225   BIC:                            -6168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.001     -1.280      0.201      -0.002       0.000
# ^GSPC          0.9888      0.052     19.071      0.000       0.887       1.090
# ==============================================================================
# Omnibus:                      547.896   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            51094.367
# Skew:                          -1.116   Prob(JB):                         0.00
# Kurtosis:                      34.534   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 22.89
# Expected Return: TGT   -0.098452
# dtype: float64
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for:
# dtype: float64
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: WMT, Date
# 2020-12-24    0.001955
# 2020-12-28    0.011986
# 2020-12-29   -0.006335
# 2020-12-30   -0.000832
# 2020-12-31   -0.000208
#                 ...
# 2025-11-06    0.002070
# 2025-11-07    0.008950
# 2025-11-10   -0.001657
# 2025-11-11    0.009959
# 2025-11-12    0.000000
# Name: WMT, Length: 1227, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.007245
# 2020-12-28    0.002786
# 2020-12-29   -0.015535
# 2020-12-30   -0.010032
# 2020-12-31   -0.009408
#                 ...
# 2025-11-06   -0.007130
# 2025-11-07   -0.000250
# 2025-11-10   -0.010857
# 2025-11-11    0.000759
# 2025-11-12   -0.009200
# Name: WMT, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: WMT    0.0684
# Name: mkt, dtype: float64
# Alpha Value: 0.0005
# Beta Value: 0.4687
# Adjusted Beta: 0.645800
# Firm Specific Risk: 0.0001
# Systematic Risk: 0.0000
# Total Risk: 0.0001698987574591212
# Error Term: Date
# 2020-12-24   -0.000209
# 2020-12-28    0.007392
# 2020-12-29   -0.005798
# 2020-12-30   -0.001967
# 2020-12-31   -0.003732
#                 ...
# 2025-11-06    0.006803
# 2025-11-07    0.007852
# 2025-11-10   -0.009382
# 2025-11-11    0.008480
# 2025-11-12   -0.000801
# Length: 1227, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    WMT   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                  0.148
# Method:                 Least Squares   F-statistic:                     214.7
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):           6.55e-45
# Time:                        13:15:04   Log-Likelihood:                 3683.4
# No. Observations:                1227   AIC:                            -7363.
# Df Residuals:                    1225   BIC:                            -7353.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      1.471      0.141      -0.000       0.001
# ^GSPC          0.4687      0.032     14.652      0.000       0.406       0.531
# ==============================================================================
# Omnibus:                      429.546   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12030.218
# Skew:                          -1.009   Prob(JB):                         0.00
# Kurtosis:                      18.207   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 14.91
# Expected Return: WMT    0.188084
# dtype: float64
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: MCD, Date
# 2020-12-24   -0.002972
# 2020-12-28    0.012442
# 2020-12-29   -0.006121
# 2020-12-30   -0.005407
# 2020-12-31    0.014275
#                 ...
# 2025-11-06   -0.023751
# 2025-11-07    0.004189
# 2025-11-10   -0.001869
# 2025-11-11    0.025844
# 2025-11-12    0.000359
# Name: MCD, Length: 1227, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.012172
# 2020-12-28    0.003242
# 2020-12-29   -0.015321
# 2020-12-30   -0.014607
# 2020-12-31    0.005075
#                 ...
# 2025-11-06   -0.032951
# 2025-11-07   -0.005011
# 2025-11-10   -0.011069
# 2025-11-11    0.016644
# 2025-11-12   -0.008841
# Name: MCD, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: MCD    0.062523
# Name: mkt, dtype: float64
# Alpha Value: 0.0002
# Beta Value: 0.4222
# Adjusted Beta: 0.614781
# Firm Specific Risk: 0.0001
# Systematic Risk: 0.0000
# Total Risk: 0.0001171445412518311
# Error Term: Date
# 2020-12-24   -0.004676
# 2020-12-28    0.008548
# 2020-12-29   -0.005392
# 2020-12-30   -0.006184
# 2020-12-31    0.011346
#                 ...
# 2025-11-06   -0.019243
# 2025-11-07    0.003445
# 2025-11-10   -0.008582
# 2025-11-11    0.024757
# 2025-11-12   -0.000118
# Length: 1227, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MCD   R-squared:                       0.175
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     260.7
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):           2.60e-53
# Time:                        13:15:04   Log-Likelihood:                 3930.8
# No. Observations:                1227   AIC:                            -7858.
# Df Residuals:                    1225   BIC:                            -7847.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.000      0.751      0.453      -0.000       0.001
# ^GSPC          0.4222      0.026     16.145      0.000       0.371       0.473
# ==============================================================================
# Omnibus:                       72.483   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              251
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     593.6
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):          3.13e-107
# Time:                        13:15:05   Log-Likelihood:                 2498.9
# No. Observations:                1227   AIC:                            -4994.
# Df Residuals:                    1225   BIC:                            -4984.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.001      0.166      0.868      -0.002       0.002
# ^GSPC          2.0464      0.084     24.364      0.000       1.882       2.211
# ==============================================================================
# Omnibus:                      142.116   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              849.911
# Skew:                           0.342   Prob(JB):                    2.78e-185
# Kurtosis:                       7.020   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 32.64
# Expected Return: TSLA    0.15296
# dtype: float64
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: GOOGL, Date
# 2020-12-24    0.003431
# 2020-12-28    0.022951
# 2020-12-29   -0.009132
# 2020-12-30   -0.012237
# 2020-12-31    0.009440
#                 ...
# 2025-11-06    0.001548
# 2025-11-07   -0.020790
# 2025-11-10    0.040419
# 2025-11-11    0.004171
# 2025-11-12   -0.015791
# Name: GOOGL, Length: 1227, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.005769
# 2020-12-28    0.013751
# 2020-12-29   -0.018332
# 2020-12-30   -0.021437
# 2020-12-31    0.000240
#                 ...
# 2025-11-06   -0.007652
# 2025-11-07   -0.029990
# 2025-11-10    0.031219
# 2025-11-11   -0.005029
# 2025-11-12   -0.024991
# Name: GOOGL, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: GOOGL    0.168841
# Name: mkt, dtype: float64
# Alpha Value: 0.0005
# Beta Value: 1.2639
# Adjusted Beta: 1.175946
# Firm Specific Risk: 0.0002
# Systematic Risk: 0.0002
# Total Risk: 0.00038397266880177953
# Error Term: Date
# 2020-12-24   -0.001504
# 2020-12-28    0.011461
# 2020-12-29   -0.006782
# 2020-12-30   -0.014398
# 2020-12-31    0.000837
#                 ...
# 2025-11-06    0.015211
# 2025-11-07   -0.022850
# 2025-11-10    0.020488
# 2025-11-11    0.001083
# 2025-11-12   -0.017051
# Length: 1227, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  GOOGL   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.479
# Method:                 Least Squares   F-statistic:                     1130.
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):          4.76e-176
# Time:                        13:15:05   Log-Likelihood:                 3485.0
# No. Observations:                1227   AIC:                            -6966.
# Df Residuals:                    1225   BIC:                            -6956.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      1.150      0.250      -0.000       0.001
# ^GSPC          1.2639      0.038     33.613      0.000       1.190       1.338
# ==============================================================================
# Omnibus:                      188.098   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2655.693
# Skew:                           0.129   Prob(JB):                         0.00
# Kurtosis:                      10.203   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 47.98
# Expected Return: GOOGL    0.281118
# dtype: float64
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: SPY, Date
# 2020-12-24    0.003890
# 2020-12-28    0.008591
# 2020-12-29   -0.001908
# 2020-12-30    0.001427
# 2020-12-31    0.005081
#                 ...
# 2025-11-06   -0.010729
# 2025-11-07    0.000985
# 2025-11-10    0.015604
# 2025-11-11    0.002289
# 2025-11-12    0.000556
# Name: SPY, Length: 1227, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.005310
# 2020-12-28   -0.000609
# 2020-12-29   -0.011108
# 2020-12-30   -0.007773
# 2020-12-31   -0.004119
#                 ...
# 2025-11-06   -0.019929
# 2025-11-07   -0.008215
# 2025-11-10    0.006404
# 2025-11-11   -0.006911
# 2025-11-12   -0.008644
# Name: SPY, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: SPY    0.136485
# Name: mkt, dtype: float64
# Alpha Value: 0.0001
# Beta Value: 1.0077
# Adjusted Beta: 1.005161
# Firm Specific Risk: 0.0000
# Systematic Risk: 0.0001
# Total Risk: 0
USD, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: STETH-USD    0.221957
# Name: mkt, dtype: float64
# Alpha Value: 0.0017
# Beta Value: 1.6844
# Adjusted Beta: 1.456299
# Firm Specific Risk: 0.0022
# Systematic Risk: 0.0003
# Total Risk: 0.002505168582536165
# Error Term: Date
# 2020-12-24    0.031606
# 2020-12-28    0.172016
# 2020-12-29   -0.006509
# 2020-12-30   -0.004349
# 2020-12-31    0.001871
#                 ...
# 2025-11-06   -0.017182
# 2025-11-07    0.033778
# 2025-11-10    0.011826
# 2025-11-11   -0.047371
# 2025-11-12   -0.005242
# Length: 1227, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              STETH-USD   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     184.0
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):           3.68e-39
# Time:                        13:15:10   Log-Likelihood:                 2019.3
# No. Observations:                1227   AIC:                            -4035.
# Df Residuals:                    1225   BIC:                            -4024.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.001      1.298      0.195      -0.001       0.004
# ^GSPC          1.6844      0.124     13.566      0.000       1.441       1.928
# ==============================================================================
# Omnibus:                      268.733   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2957.660
# Skew:                           0.679   Prob(JB):                         0.00
# Kurtosis:                      10.484   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 13.06
# Expected Return: STETH-USD    0.434217
# dtype: float64
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: TRX-USD, Date
# 2020-12-24    0.115915
# 2020-12-28    0.066253
# 2020-12-29   -0.062373
# 2020-12-30   -0.026905
# 2020-12-31   -0.004157
#                 ...
# 2025-11-06   -0.018532
# 2025-11-07    0.029375
# 2025-11-10    0.014628
# 2025-11-11    0.001417
# 2025-11-12   -0.007347
# Name: TRX-USD, Length: 1227, dtype: float64
# Excess Returns: Date
# 2020-12-24    0.106715
# 2020-12-28    0.057053
# 2020-12-29   -0.071573
# 2020-12-30   -0.036105
# 2020-12-31   -0.013357
#                 ...
# 2025-11-06   -0.027732
# 2025-11-07    0.020175
# 2025-11-10    0.005428
# 2025-11-11   -0.007783
# 2025-11-12   -0.016547
# Name: TRX-USD, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: TRX-USD    0.132979
# Name: mkt, dtype: float64
# Alpha Value: 0.0028
# Beta Value: 0.9800
# Adjusted Beta: 0.986660
# Firm Specific Risk: 0.0028
# Systematic Risk: 0.0001
# Total Risk: 0.0029463532640280608
# Error Term: Date
# 2020-12-24    0.109673
# 2020-12-28    0.054929
# 2020-12-29   -0.062966
# 2020-12-30   -0.030996
# 2020-12-31   -0.013242
#                 ...
# 2025-11-06   -0.010354
# 2025-11-07    0.025363
# 2025-11-10   -0.003241
# 2025-11-11   -0.003392
# 2025-11-12   -0.010739
# Length: 1227, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRX-USD   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     47.85
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):           7.41e-12
# Time:                        13:15:11   Log-Likelihood:                 1857.4
# No. Observations:                1227   AIC:                            -3711.
# Df Residuals:                    1225   BIC:                            -3701.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0028      0.002      1.822      0.069      -0.000       0.006
# ^GSPC          0.9800      0.142      6.917      0.000       0.702       1.258
# ==============================================================================
# Omnibus:                     1445.729   Durbin-Watson:                   2.261
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           423041.520
# Skew:                           5.508   Prob(JB):                         0.00
# Kurtosis:                      93.296   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 3.76
# Expected Return: TRX-USD    0.662078
# dtype: float64
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: LINK-USD, Date
# 2020-12-24    0.068703
# 2020-12-28    0.090962
# 2020-12-29   -0.067883
# 2020-12-30   -0.043968
# 2020-12-31    0.001507
#                 ...
# 2025-11-06   -0.028623
# 2025-11-07    0.071509
# 2025-11-10    0.036476
# 2025-11-11   -0.063993
# 2025-11-12   -0.010236
# Name: LINK-USD, Length: 1227, dtype: float64
# Excess Returns: Date
# 2020-12-24    0.059503
# 2020-12-28    0.081762
# 2020-12-29   -0.077083
# 2020-12-30   -0.053168
# 2020-12-31   -0.007693
#                 ...
# 2025-11-06   -0.037823
# 2025-11-07    0.062309
# 2025-11-10    0.027276
# 2025-11-11   -0.073193
# 2025-11-12   -0.019436
# Name: LINK-USD, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: LINK-USD    0.254382
# Name: mkt, dtype: float64
# Alpha Value: 0.0011
# Beta Value: 1.9412
# Adjusted Beta: 1.627442
# Firm Specific Risk: 0.0035
# Systematic Risk: 0.0004
# Total Risk: 0.0038861508104290994
# Error Term: Date
# 2020-12-24    0.060705
# 2020-12-28    0.072897
# 2020-12-29   -0.064693
# 2020-12-30   -0.047705
# 2020-12-31   -0.012125
#                 ...
# 2025-11-06   -0.008058
# 2025-11-07    0.067926
# 2025-11-10    0.005447
# 2025-11-11   -0.069154
# 2025-11-12   -0.012591
# Length: 1227, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LINK-USD   R-squared:                       0.112
# Model:                            OLS   Adj. R-squared:                  0.111
# Method:                 Least Squares   F-statistic:                     154.2
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):           1.94e-33
# Time:                        13:15:11   Log-Likelihood:                 1736.8
# No. Observations:                1227   AIC:                            -3470.
# Df Residuals:                    1225   BIC:                            -3459.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.002      0.674      0.500      -0.002       0.004
# ^GSPC          1.9412      0.156     12.419      0.000       1.634       2.248
# ==============================================================================
# Omnibus:                      175.196   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1279.638
# Skew:                           0.425   Prob(JB):                    1.35e-278
# Kurtosis:                       7.930   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 11.18
# Expected Return: LINK-USD    0.071227
# dtype: float64
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: ^GSPC, Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.005663
# 2020-12-28   -0.000477
# 2020-12-29   -0.011427
# 2020-12-30   -0.007858
# 2020-12-31   -0.002761
#                 ...
# 2025-11-06   -0.020378
# 2025-11-07   -0.007938
# 2025-11-10    0.006201
# 2025-11-11   -0.007125
# 2025-11-12   -0.008570
# Name: ^GSPC, Length: 1227, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-11-06   -0.011178
# 2025-11-07    0.001262
# 2025-11-10    0.015401
# 2025-11-11    0.002075
# 2025-11-12    0.000630
# Name: ^GSPC, Length: 1227, dtype: float64;-----
# CAPM Returns: ^GSPC    0.135507
# Name: mkt, dtype: float64
# Alpha Value: -0.0000
# Beta Value: 1.0000
# Adjusted Beta: 1.000000
# Firm Specific Risk: 0.0000
# Systematic Risk: 0.0001
# Total Risk: 0.00011532164066975053
# Error Term: Date
# 2020-12-24    1.734723e-18
# 2020-12-28    3.469447e-18
# 2020-12-29   -8.673617e-19
# 2020-12-30    6.505213e-19
# 2020-12-31    2.602085e-18
#                   ...
# 2025-11-06   -5.204170e-18
# 2025-11-07    6.505213e-19
# 2025-11-10    6.938894e-18
# 2025-11-11    8.673617e-19
# 2025-11-12    4.336809e-19
# Length: 1227, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ^GSPC   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 6.210e+33
# Date:                Fri, 14 Nov 2025   Prob (F-statistic):               0.00
# Time:                        13:15:12   Log-Likelihood:                 47197.
# No. Observations:                1227   AIC:                        -9.439e+04
# Df Residuals:                    1225   BIC:                        -9.438e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -5.59e-20   1.36e-19     -0.410      0.682   -3.24e-19    2.12e-19
# ^GSPC          1.0000   1.27e-17   7.88e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                      190.492   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2748.966
# Skew:                           0.135   Prob(JB):                         0.00
# Kurtosis:                      10.328   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 100.00
# Expected Return: ^GSPC    0.135507
# dtype: float64
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:240: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:254: RuntimeWarning: market prices are not in a dataframe
#   warnings.warn("market prices are not in a dataframe", RuntimeWarning)
# /home/nickkats1/Portfolio/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
